# %% [markdown]
# ## 1. Read in & clean data

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
plant_data = pd.read_csv("all-plant-data.csv")
plant_data
# Out:
#                                         scientific_name  \
# 0                                      Abelia chinensis
# 1                               Abelia 'Edward Goucher'
# 2                                  Abelia × grandiflora
# 3             Abelia × grandiflora 'Hopleys' MISS LEMON
# 4                   Abelia × grandiflora 'Kaleidoscope'
# ...                                                 ...
# 8443          Diervilla rivularis 'Morton' SUMMER STARS
# 8444                             Diervilla sessilifolia
# 8445  Diervilla sessilifolia 'LPDC Podaras' COOL SPLASH
# 8446  Diervilla splendens 'El Madrigal' FIREFLY NIGH...
# 8447                                     Dietes bicolor
#
#                     common_name          family height (feet)  height_min  \
# 0                Chinese Abelia  Caprifoliaceae  5.00 to 8.00         5.0
# 1                        Abelia  Caprifoliaceae  3.00 to 5.00         3.0
# 2                 Glossy Abelia  Caprifoliaceae  3.00 to 6.00         3.0
# 3                 Glossy Abelia  Caprifoliaceae  3.00 to 4.00         3.0
# 4                 Glossy Abelia  Caprifoliaceae  2.00 to 2.50         2.0
# ...                         ...             ...           ...         ...
# 8443  Mountain Bush Honeysuckle  Caprifoliaceae  2.00 to 3.00         2.0
# 8444           Bush Honeysuckle  Caprifoliaceae  3.00 to 5.00         3.0
# 8445  Southern Bush Honeysuckle  Caprifoliaceae  2.00 to 3.00         2.0
# 8446           Bush Honeysuckle  Caprifoliaceae  2.00 to 3.00         2.0
# 8447             Butterfly Flag       Iridaceae  1.50 to 2.00         1.5
#
#       height_max spread (feet)  spread_min  spread_max             type  ...  \
# 0            8.0  3.00 to 5.00        3.00         5.0  Deciduous shrub  ...
# 1            5.0  3.00 to 5.00        3.00         5.0  Deciduous shrub  ...
# 2            6.0  3.00 to 6.00        3.00         6.0  Deciduous shrub  ...
# 3            4.0  3.00 to 4.00        3.00         4.0  Deciduous shrub  ...
# 4            2.5  3.00 to 4.00        3.00         4.0  Deciduous shrub  ...
# ...          ...           ...         ...         ...              ...  ...
# 8443         3.0  3.00 to 4.00        3.00         4.0  Deciduous shrub  ...
# 8444         5.0  3.00 to 5.00        3.00         5.0  Deciduous shrub  ...
# 8445         3.0  2.00 to 3.00        2.00         3.0  Deciduous shrub  ...
# 8446         3.0  2.00 to 3.00        2.00         3.0  Deciduous shrub  ...
# 8447         2.0  0.75 to 1.00        0.75         1.0             Bulb  ...
#
#      maintenance                     sun   sun_max     sun_min   water  \
# 0            Low  Full sun to part shade  full sun  part shade  Medium
# 1            Low  Full sun to part shade  full sun  part shade  Medium
# 2            Low  Full sun to part shade  full sun  part shade  Medium
# 3            Low  Full sun to part shade  full sun  part shade  Medium
# 4            Low  Full sun to part shade  full sun  part shade  Medium
# ...          ...                     ...       ...         ...     ...
# 8443         Low  Full sun to part shade  full sun  part shade  Medium
# 8444      Medium  Full sun to part shade  full sun  part shade  Medium
# 8445      Medium  Full sun to part shade  full sun  part shade  Medium
# 8446         Low                Full sun  full sun         NaN  Medium
# 8447         Low  Full sun to part shade  full sun  part shade  Medium
#
#          zone zone_min zone_max                                   bloom_desc  \
# 0      7 to 9      7.0      9.0                                        White
# 1      6 to 9      6.0      9.0                              Lavender - pink
# 2      5 to 9      5.0      9.0                           White/flushed pink
# 3      6 to 9      6.0      9.0                 Light pink to white or lilac
# 4      5 to 9      5.0      9.0                                        White
# ...       ...      ...      ...                                          ...
# 8443   5 to 7      5.0      7.0                                       Yellow
# 8444   5 to 8      5.0      8.0                                Sulfur yellow
# 8445   4 to 8      4.0      8.0                                       Yellow
# 8446   4 to 8      4.0      8.0                                       Yellow
# 8447  9 to 11      9.0     11.0  Light yellow with dark brown tepal blotches
#
#                      native_range
# 0                           China
# 1                             NaN
# 2                  origin unknown
# 3                             NaN
# 4                             NaN
# ...                           ...
# 8443                          NaN
# 8444   Southeastern United States
# 8445                          NaN
# 8446                          NaN
# 8447                 South Africa
#
# [8448 rows x 23 columns]

# %%
plant_data.head()
# Out:
#                              scientific_name     common_name          family  \
# 0                           Abelia chinensis  Chinese Abelia  Caprifoliaceae
# 1                    Abelia 'Edward Goucher'          Abelia  Caprifoliaceae
# 2                       Abelia × grandiflora   Glossy Abelia  Caprifoliaceae
# 3  Abelia × grandiflora 'Hopleys' MISS LEMON   Glossy Abelia  Caprifoliaceae
# 4        Abelia × grandiflora 'Kaleidoscope'   Glossy Abelia  Caprifoliaceae
#
#   height (feet)  height_min  height_max spread (feet)  spread_min  spread_max  \
# 0  5.00 to 8.00         5.0         8.0  3.00 to 5.00         3.0         5.0
# 1  3.00 to 5.00         3.0         5.0  3.00 to 5.00         3.0         5.0
# 2  3.00 to 6.00         3.0         6.0  3.00 to 6.00         3.0         6.0
# 3  3.00 to 4.00         3.0         4.0  3.00 to 4.00         3.0         4.0
# 4  2.00 to 2.50         2.0         2.5  3.00 to 4.00         3.0         4.0
#
#               type  ... maintenance                     sun   sun_max  \
# 0  Deciduous shrub  ...         Low  Full sun to part shade  full sun
# 1  Deciduous shrub  ...         Low  Full sun to part shade  full sun
# 2  Deciduous shrub  ...         Low  Full sun to part shade  full sun
# 3  Deciduous shrub  ...         Low  Full sun to part shade  full sun
# 4  Deciduous shrub  ...         Low  Full sun to part shade  full sun
#
#       sun_min   water    zone zone_min zone_max                    bloom_desc  \
# 0  part shade  Medium  7 to 9      7.0      9.0                         White
# 1  part shade  Medium  6 to 9      6.0      9.0               Lavender - pink
# 2  part shade  Medium  5 to 9      5.0      9.0            White/flushed pink
# 3  part shade  Medium  6 to 9      6.0      9.0  Light pink to white or lilac
# 4  part shade  Medium  5 to 9      5.0      9.0                         White
#
#       native_range
# 0            China
# 1              NaN
# 2   origin unknown
# 3              NaN
# 4              NaN
#
# [5 rows x 23 columns]

# %%
plant_data.dtypes
# Out:
# scientific_name     object
# common_name         object
# family              object
# height (feet)       object
# height_min         float64
# height_max         float64
# spread (feet)       object
# spread_min         float64
# spread_max         float64
# type                object
# bloom_time          object
# bloom_start         object
# bloom_end           object
# maintenance         object
# sun                 object
# sun_max             object
# sun_min             object
# water               object
# zone                object
# zone_min           float64
# zone_max           float64
# bloom_desc          object
# native_range        object
# dtype: object

# %% [markdown]
# This dataset was previously cleaned in OpenRefine to split columns that express values in a range into separate min/max columns. Here we should drop those original columns since they are still expressed as objects instead of floats.

# %%
plant_data = plant_data.drop(columns=['height (feet)', 'spread (feet)', 'bloom_time', 'sun', 'zone','native_range'])

# %%
plant_data.dtypes
# Out:
# scientific_name     object
# common_name         object
# family              object
# height_min         float64
# height_max         float64
# spread_min         float64
# spread_max         float64
# type                object
# bloom_start         object
# bloom_end           object
# maintenance         object
# sun_max             object
# sun_min             object
# water               object
# zone_min           float64
# zone_max           float64
# bloom_desc          object
# dtype: object

# %%
plant_data.isna().sum()
# Out:
# scientific_name       0
# common_name          12
# family                0
# height_min            0
# height_max            0
# spread_min            2
# spread_max            2
# type                  4
# bloom_start           4
# bloom_end          2488
# maintenance           5
# sun_max               6
# sun_min            3579
# water                 6
# zone_min             11
# zone_max             15
# bloom_desc          174
# dtype: int64

# %% [markdown]
# Convert Bloom Start and Bloom End to Date-Time

# %%
plant_data["bloom_start"] = plant_data["bloom_start"].astype(str)
plant_data["bloom_end"] = plant_data["bloom_end"].astype(str)

# %%
plant_data[["bloom_start", "bloom_end"]] = plant_data[["bloom_start", "bloom_end"]].apply(pd.to_datetime, format="%B", errors="coerce")

# %%
# extracting month

plant_data["bloom_start_month"] = plant_data["bloom_start"].apply(lambda x: x.month)
plant_data["bloom_end_month"] = plant_data["bloom_end"].apply(lambda x: x.month)

# %%
plant_data
# Out:
#                                         scientific_name  \
# 0                                      Abelia chinensis
# 1                               Abelia 'Edward Goucher'
# 2                                  Abelia × grandiflora
# 3             Abelia × grandiflora 'Hopleys' MISS LEMON
# 4                   Abelia × grandiflora 'Kaleidoscope'
# ...                                                 ...
# 8443          Diervilla rivularis 'Morton' SUMMER STARS
# 8444                             Diervilla sessilifolia
# 8445  Diervilla sessilifolia 'LPDC Podaras' COOL SPLASH
# 8446  Diervilla splendens 'El Madrigal' FIREFLY NIGH...
# 8447                                     Dietes bicolor
#
#                     common_name          family  height_min  height_max  \
# 0                Chinese Abelia  Caprifoliaceae         5.0         8.0
# 1                        Abelia  Caprifoliaceae         3.0         5.0
# 2                 Glossy Abelia  Caprifoliaceae         3.0         6.0
# 3                 Glossy Abelia  Caprifoliaceae         3.0         4.0
# 4                 Glossy Abelia  Caprifoliaceae         2.0         2.5
# ...                         ...             ...         ...         ...
# 8443  Mountain Bush Honeysuckle  Caprifoliaceae         2.0         3.0
# 8444           Bush Honeysuckle  Caprifoliaceae         3.0         5.0
# 8445  Southern Bush Honeysuckle  Caprifoliaceae         2.0         3.0
# 8446           Bush Honeysuckle  Caprifoliaceae         2.0         3.0
# 8447             Butterfly Flag       Iridaceae         1.5         2.0
#
#       spread_min  spread_max             type bloom_start  bloom_end  \
# 0           3.00         5.0  Deciduous shrub  1900-07-01 1900-09-01
# 1           3.00         5.0  Deciduous shrub  1900-05-01 1900-09-01
# 2           3.00         6.0  Deciduous shrub  1900-05-01 1900-09-01
# 3           3.00         4.0  Deciduous shrub  1900-05-01 1900-09-01
# 4           3.00         4.0  Deciduous shrub  1900-05-01 1900-09-01
# ...          ...         ...              ...         ...        ...
# 8443        3.00         4.0  Deciduous shrub  1900-07-01 1900-08-01
# 8444        3.00         5.0  Deciduous shrub  1900-06-01 1900-07-01
# 8445        2.00         3.0  Deciduous shrub  1900-06-01 1900-07-01
# 8446        2.00         3.0  Deciduous shrub  1900-05-01 1900-07-01
# 8447        0.75         1.0             Bulb  1900-05-01 1900-09-01
#
#      maintenance   sun_max     sun_min   water  zone_min  zone_max  \
# 0            Low  full sun  part shade  Medium       7.0       9.0
# 1            Low  full sun  part shade  Medium       6.0       9.0
# 2            Low  full sun  part shade  Medium       5.0       9.0
# 3            Low  full sun  part shade  Medium       6.0       9.0
# 4            Low  full sun  part shade  Medium       5.0       9.0
# ...          ...       ...         ...     ...       ...       ...
# 8443         Low  full sun  part shade  Medium       5.0       7.0
# 8444      Medium  full sun  part shade  Medium       5.0       8.0
# 8445      Medium  full sun  part shade  Medium       4.0       8.0
# 8446         Low  full sun         NaN  Medium       4.0       8.0
# 8447         Low  full sun  part shade  Medium       9.0      11.0
#
#                                        bloom_desc  bloom_start_month  \
# 0                                           White                7.0
# 1                                 Lavender - pink                5.0
# 2                              White/flushed pink                5.0
# 3                    Light pink to white or lilac                5.0
# 4                                           White                5.0
# ...                                           ...                ...
# 8443                                       Yellow                7.0
# 8444                                Sulfur yellow                6.0
# 8445                                       Yellow                6.0
# 8446                                       Yellow                5.0
# 8447  Light yellow with dark brown tepal blotches                5.0
#
#       bloom_end_month
# 0                 9.0
# 1                 9.0
# 2                 9.0
# 3                 9.0
# 4                 9.0
# ...               ...
# 8443              8.0
# 8444              7.0
# 8445              7.0
# 8446              7.0
# 8447              9.0
#
# [8448 rows x 19 columns]

# %%
plant_data = plant_data.drop(columns=['bloom_start', 'bloom_end'])

# %%
plant_data = plant_data.set_index("scientific_name")

# %%
plant_data
# Out:
#                                                                   common_name  \
# scientific_name
# Abelia chinensis                                               Chinese Abelia
# Abelia 'Edward Goucher'                                                Abelia
# Abelia × grandiflora                                            Glossy Abelia
# Abelia × grandiflora 'Hopleys' MISS LEMON                       Glossy Abelia
# Abelia × grandiflora 'Kaleidoscope'                             Glossy Abelia
# ...                                                                       ...
# Diervilla rivularis 'Morton' SUMMER STARS           Mountain Bush Honeysuckle
# Diervilla sessilifolia                                       Bush Honeysuckle
# Diervilla sessilifolia 'LPDC Podaras' COOL SPLASH   Southern Bush Honeysuckle
# Diervilla splendens 'El Madrigal' FIREFLY NIGHT...           Bush Honeysuckle
# Dietes bicolor                                                 Butterfly Flag
#
#                                                             family  \
# scientific_name
# Abelia chinensis                                    Caprifoliaceae
# Abelia 'Edward Goucher'                             Caprifoliaceae
# Abelia × grandiflora                                Caprifoliaceae
# Abelia × grandiflora 'Hopleys' MISS LEMON           Caprifoliaceae
# Abelia × grandiflora 'Kaleidoscope'                 Caprifoliaceae
# ...                                                            ...
# Diervilla rivularis 'Morton' SUMMER STARS           Caprifoliaceae
# Diervilla sessilifolia                              Caprifoliaceae
# Diervilla sessilifolia 'LPDC Podaras' COOL SPLASH   Caprifoliaceae
# Diervilla splendens 'El Madrigal' FIREFLY NIGHT...  Caprifoliaceae
# Dietes bicolor                                           Iridaceae
#
#                                                     height_min  height_max  \
# scientific_name
# Abelia chinensis                                           5.0         8.0
# Abelia 'Edward Goucher'                                    3.0         5.0
# Abelia × grandiflora                                       3.0         6.0
# Abelia × grandiflora 'Hopleys' MISS LEMON                  3.0         4.0
# Abelia × grandiflora 'Kaleidoscope'                        2.0         2.5
# ...                                                        ...         ...
# Diervilla rivularis 'Morton' SUMMER STARS                  2.0         3.0
# Diervilla sessilifolia                                     3.0         5.0
# Diervilla sessilifolia 'LPDC Podaras' COOL SPLASH          2.0         3.0
# Diervilla splendens 'El Madrigal' FIREFLY NIGHT...         2.0         3.0
# Dietes bicolor                                             1.5         2.0
#
#                                                     spread_min  spread_max  \
# scientific_name
# Abelia chinensis                                          3.00         5.0
# Abelia 'Edward Goucher'                                   3.00         5.0
# Abelia × grandiflora                                      3.00         6.0
# Abelia × grandiflora 'Hopleys' MISS LEMON                 3.00         4.0
# Abelia × grandiflora 'Kaleidoscope'                       3.00         4.0
# ...                                                        ...         ...
# Diervilla rivularis 'Morton' SUMMER STARS                 3.00         4.0
# Diervilla sessilifolia                                    3.00         5.0
# Diervilla sessilifolia 'LPDC Podaras' COOL SPLASH         2.00         3.0
# Diervilla splendens 'El Madrigal' FIREFLY NIGHT...        2.00         3.0
# Dietes bicolor                                            0.75         1.0
#
#                                                                type  \
# scientific_name
# Abelia chinensis                                    Deciduous shrub
# Abelia 'Edward Goucher'                             Deciduous shrub
# Abelia × grandiflora                                Deciduous shrub
# Abelia × grandiflora 'Hopleys' MISS LEMON           Deciduous shrub
# Abelia × grandiflora 'Kaleidoscope'                 Deciduous shrub
# ...                                                             ...
# Diervilla rivularis 'Morton' SUMMER STARS           Deciduous shrub
# Diervilla sessilifolia                              Deciduous shrub
# Diervilla sessilifolia 'LPDC Podaras' COOL SPLASH   Deciduous shrub
# Diervilla splendens 'El Madrigal' FIREFLY NIGHT...  Deciduous shrub
# Dietes bicolor                                                 Bulb
#
#                                                    maintenance   sun_max  \
# scientific_name
# Abelia chinensis                                           Low  full sun
# Abelia 'Edward Goucher'                                    Low  full sun
# Abelia × grandiflora                                       Low  full sun
# Abelia × grandiflora 'Hopleys' MISS LEMON                  Low  full sun
# Abelia × grandiflora 'Kaleidoscope'                        Low  full sun
# ...                                                        ...       ...
# Diervilla rivularis 'Morton' SUMMER STARS                  Low  full sun
# Diervilla sessilifolia                                  Medium  full sun
# Diervilla sessilifolia 'LPDC Podaras' COOL SPLASH       Medium  full sun
# Diervilla splendens 'El Madrigal' FIREFLY NIGHT...         Low  full sun
# Dietes bicolor                                             Low  full sun
#
#                                                        sun_min   water  \
# scientific_name
# Abelia chinensis                                    part shade  Medium
# Abelia 'Edward Goucher'                             part shade  Medium
# Abelia × grandiflora                                part shade  Medium
# Abelia × grandiflora 'Hopleys' MISS LEMON           part shade  Medium
# Abelia × grandiflora 'Kaleidoscope'                 part shade  Medium
# ...                                                        ...     ...
# Diervilla rivularis 'Morton' SUMMER STARS           part shade  Medium
# Diervilla sessilifolia                              part shade  Medium
# Diervilla sessilifolia 'LPDC Podaras' COOL SPLASH   part shade  Medium
# Diervilla splendens 'El Madrigal' FIREFLY NIGHT...         NaN  Medium
# Dietes bicolor                                      part shade  Medium
#
#                                                     zone_min  zone_max  \
# scientific_name
# Abelia chinensis                                         7.0       9.0
# Abelia 'Edward Goucher'                                  6.0       9.0
# Abelia × grandiflora                                     5.0       9.0
# Abelia × grandiflora 'Hopleys' MISS LEMON                6.0       9.0
# Abelia × grandiflora 'Kaleidoscope'                      5.0       9.0
# ...                                                      ...       ...
# Diervilla rivularis 'Morton' SUMMER STARS                5.0       7.0
# Diervilla sessilifolia                                   5.0       8.0
# Diervilla sessilifolia 'LPDC Podaras' COOL SPLASH        4.0       8.0
# Diervilla splendens 'El Madrigal' FIREFLY NIGHT...       4.0       8.0
# Dietes bicolor                                           9.0      11.0
#
#                                                                                      bloom_desc  \
# scientific_name
# Abelia chinensis                                                                          White
# Abelia 'Edward Goucher'                                                         Lavender - pink
# Abelia × grandiflora                                                         White/flushed pink
# Abelia × grandiflora 'Hopleys' MISS LEMON                          Light pink to white or lilac
# Abelia × grandiflora 'Kaleidoscope'                                                       White
# ...                                                                                         ...
# Diervilla rivularis 'Morton' SUMMER STARS                                                Yellow
# Diervilla sessilifolia                                                            Sulfur yellow
# Diervilla sessilifolia 'LPDC Podaras' COOL SPLASH                                        Yellow
# Diervilla splendens 'El Madrigal' FIREFLY NIGHT...                                       Yellow
# Dietes bicolor                                      Light yellow with dark brown tepal blotches
#
#                                                     bloom_start_month  \
# scientific_name
# Abelia chinensis                                                  7.0
# Abelia 'Edward Goucher'                                           5.0
# Abelia × grandiflora                                              5.0
# Abelia × grandiflora 'Hopleys' MISS LEMON                         5.0
# Abelia × grandiflora 'Kaleidoscope'                               5.0
# ...                                                               ...
# Diervilla rivularis 'Morton' SUMMER STARS                         7.0
# Diervilla sessilifolia                                            6.0
# Diervilla sessilifolia 'LPDC Podaras' COOL SPLASH                 6.0
# Diervilla splendens 'El Madrigal' FIREFLY NIGHT...                5.0
# Dietes bicolor                                                    5.0
#
#                                                     bloom_end_month
# scientific_name
# Abelia chinensis                                                9.0
# Abelia 'Edward Goucher'                                         9.0
# Abelia × grandiflora                                            9.0
# Abelia × grandiflora 'Hopleys' MISS LEMON                       9.0
# Abelia × grandiflora 'Kaleidoscope'                             9.0
# ...                                                             ...
# Diervilla rivularis 'Morton' SUMMER STARS                       8.0
# Diervilla sessilifolia                                          7.0
# Diervilla sessilifolia 'LPDC Podaras' COOL SPLASH               7.0
# Diervilla splendens 'El Madrigal' FIREFLY NIGHT...              7.0
# Dietes bicolor                                                  9.0
#
# [8448 rows x 16 columns]

# %%
plant_data.dtypes
# Out:
# common_name           object
# family                object
# height_min           float64
# height_max           float64
# spread_min           float64
# spread_max           float64
# type                  object
# maintenance           object
# sun_max               object
# sun_min               object
# water                 object
# zone_min             float64
# zone_max             float64
# bloom_desc            object
# bloom_start_month    float64
# bloom_end_month      float64
# dtype: object

# %%
plant_data_nona = plant_data.dropna()

# %%
plant_data_nona
# Out:
#                                                                  common_name  \
# scientific_name
# Abelia chinensis                                              Chinese Abelia
# Abelia 'Edward Goucher'                                               Abelia
# Abelia × grandiflora                                           Glossy Abelia
# Abelia × grandiflora 'Hopleys' MISS LEMON                      Glossy Abelia
# Abelia × grandiflora 'Kaleidoscope'                            Glossy Abelia
# ...                                                                      ...
# Diervilla rivularis                                Mountain Bush Honeysuckle
# Diervilla rivularis 'Morton' SUMMER STARS          Mountain Bush Honeysuckle
# Diervilla sessilifolia                                      Bush Honeysuckle
# Diervilla sessilifolia 'LPDC Podaras' COOL SPLASH  Southern Bush Honeysuckle
# Dietes bicolor                                                Butterfly Flag
#
#                                                            family  height_min  \
# scientific_name
# Abelia chinensis                                   Caprifoliaceae         5.0
# Abelia 'Edward Goucher'                            Caprifoliaceae         3.0
# Abelia × grandiflora                               Caprifoliaceae         3.0
# Abelia × grandiflora 'Hopleys' MISS LEMON          Caprifoliaceae         3.0
# Abelia × grandiflora 'Kaleidoscope'                Caprifoliaceae         2.0
# ...                                                           ...         ...
# Diervilla rivularis                                Caprifoliaceae         3.0
# Diervilla rivularis 'Morton' SUMMER STARS          Caprifoliaceae         2.0
# Diervilla sessilifolia                             Caprifoliaceae         3.0
# Diervilla sessilifolia 'LPDC Podaras' COOL SPLASH  Caprifoliaceae         2.0
# Dietes bicolor                                          Iridaceae         1.5
#
#                                                    height_max  spread_min  \
# scientific_name
# Abelia chinensis                                          8.0        3.00
# Abelia 'Edward Goucher'                                   5.0        3.00
# Abelia × grandiflora                                      6.0        3.00
# Abelia × grandiflora 'Hopleys' MISS LEMON                 4.0        3.00
# Abelia × grandiflora 'Kaleidoscope'                       2.5        3.00
# ...                                                       ...         ...
# Diervilla rivularis                                       6.0        4.00
# Diervilla rivularis 'Morton' SUMMER STARS                 3.0        3.00
# Diervilla sessilifolia                                    5.0        3.00
# Diervilla sessilifolia 'LPDC Podaras' COOL SPLASH         3.0        2.00
# Dietes bicolor                                            2.0        0.75
#
#                                                    spread_max  \
# scientific_name
# Abelia chinensis                                          5.0
# Abelia 'Edward Goucher'                                   5.0
# Abelia × grandiflora                                      6.0
# Abelia × grandiflora 'Hopleys' MISS LEMON                 4.0
# Abelia × grandiflora 'Kaleidoscope'                       4.0
# ...                                                       ...
# Diervilla rivularis                                       8.0
# Diervilla rivularis 'Morton' SUMMER STARS                 4.0
# Diervilla sessilifolia                                    5.0
# Diervilla sessilifolia 'LPDC Podaras' COOL SPLASH         3.0
# Dietes bicolor                                            1.0
#
#                                                               type  \
# scientific_name
# Abelia chinensis                                   Deciduous shrub
# Abelia 'Edward Goucher'                            Deciduous shrub
# Abelia × grandiflora                               Deciduous shrub
# Abelia × grandiflora 'Hopleys' MISS LEMON          Deciduous shrub
# Abelia × grandiflora 'Kaleidoscope'                Deciduous shrub
# ...                                                            ...
# Diervilla rivularis                                Deciduous shrub
# Diervilla rivularis 'Morton' SUMMER STARS          Deciduous shrub
# Diervilla sessilifolia                             Deciduous shrub
# Diervilla sessilifolia 'LPDC Podaras' COOL SPLASH  Deciduous shrub
# Dietes bicolor                                                Bulb
#
#                                                   maintenance   sun_max  \
# scientific_name
# Abelia chinensis                                          Low  full sun
# Abelia 'Edward Goucher'                                   Low  full sun
# Abelia × grandiflora                                      Low  full sun
# Abelia × grandiflora 'Hopleys' MISS LEMON                 Low  full sun
# Abelia × grandiflora 'Kaleidoscope'                       Low  full sun
# ...                                                       ...       ...
# Diervilla rivularis                                       Low  full sun
# Diervilla rivularis 'Morton' SUMMER STARS                 Low  full sun
# Diervilla sessilifolia                                 Medium  full sun
# Diervilla sessilifolia 'LPDC Podaras' COOL SPLASH      Medium  full sun
# Dietes bicolor                                            Low  full sun
#
#                                                       sun_min   water  \
# scientific_name
# Abelia chinensis                                   part shade  Medium
# Abelia 'Edward Goucher'                            part shade  Medium
# Abelia × grandiflora                               part shade  Medium
# Abelia × grandiflora 'Hopleys' MISS LEMON          part shade  Medium
# Abelia × grandiflora 'Kaleidoscope'                part shade  Medium
# ...                                                       ...     ...
# Diervilla rivularis                                part shade  Medium
# Diervilla rivularis 'Morton' SUMMER STARS          part shade  Medium
# Diervilla sessilifolia                             part shade  Medium
# Diervilla sessilifolia 'LPDC Podaras' COOL SPLASH  part shade  Medium
# Dietes bicolor                                     part shade  Medium
#
#                                                    zone_min  zone_max  \
# scientific_name
# Abelia chinensis                                        7.0       9.0
# Abelia 'Edward Goucher'                                 6.0       9.0
# Abelia × grandiflora                                    5.0       9.0
# Abelia × grandiflora 'Hopleys' MISS LEMON               6.0       9.0
# Abelia × grandiflora 'Kaleidoscope'                     5.0       9.0
# ...                                                     ...       ...
# Diervilla rivularis                                     5.0       7.0
# Diervilla rivularis 'Morton' SUMMER STARS               5.0       7.0
# Diervilla sessilifolia                                  5.0       8.0
# Diervilla sessilifolia 'LPDC Podaras' COOL SPLASH       4.0       8.0
# Dietes bicolor                                          9.0      11.0
#
#                                                                                     bloom_desc  \
# scientific_name
# Abelia chinensis                                                                         White
# Abelia 'Edward Goucher'                                                        Lavender - pink
# Abelia × grandiflora                                                        White/flushed pink
# Abelia × grandiflora 'Hopleys' MISS LEMON                         Light pink to white or lilac
# Abelia × grandiflora 'Kaleidoscope'                                                      White
# ...                                                                                        ...
# Diervilla rivularis                                                                     Yellow
# Diervilla rivularis 'Morton' SUMMER STARS                                               Yellow
# Diervilla sessilifolia                                                           Sulfur yellow
# Diervilla sessilifolia 'LPDC Podaras' COOL SPLASH                                       Yellow
# Dietes bicolor                                     Light yellow with dark brown tepal blotches
#
#                                                    bloom_start_month  \
# scientific_name
# Abelia chinensis                                                 7.0
# Abelia 'Edward Goucher'                                          5.0
# Abelia × grandiflora                                             5.0
# Abelia × grandiflora 'Hopleys' MISS LEMON                        5.0
# Abelia × grandiflora 'Kaleidoscope'                              5.0
# ...                                                              ...
# Diervilla rivularis                                              7.0
# Diervilla rivularis 'Morton' SUMMER STARS                        7.0
# Diervilla sessilifolia                                           6.0
# Diervilla sessilifolia 'LPDC Podaras' COOL SPLASH                6.0
# Dietes bicolor                                                   5.0
#
#                                                    bloom_end_month
# scientific_name
# Abelia chinensis                                               9.0
# Abelia 'Edward Goucher'                                        9.0
# Abelia × grandiflora                                           9.0
# Abelia × grandiflora 'Hopleys' MISS LEMON                      9.0
# Abelia × grandiflora 'Kaleidoscope'                            9.0
# ...                                                            ...
# Diervilla rivularis                                            8.0
# Diervilla rivularis 'Morton' SUMMER STARS                      8.0
# Diervilla sessilifolia                                         7.0
# Diervilla sessilifolia 'LPDC Podaras' COOL SPLASH              7.0
# Dietes bicolor                                                 9.0
#
# [3298 rows x 16 columns]

# %% [markdown]
# Encode categorical features and normalizing data.

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# %%
numeric_features = plant_data.select_dtypes(exclude='O').columns

numeric_transformer = Pipeline(
    steps=[("scaler", StandardScaler())]
)

categorical_features = plant_data.select_dtypes(include='O').columns

categorical_transformer = OneHotEncoder(handle_unknown="ignore")

preprocessor = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, numeric_features),
        ("cat", categorical_transformer, categorical_features),
    ]
)

# %%
processing_pipe = Pipeline(
    steps=[("preprocessor", preprocessor)]
)

# %%
processed_plant_data = processing_pipe.fit_transform(plant_data)

# %% [markdown]
# Convert data to an array and reassign index to processed dataframe.

# %%
plant_data_df = pd.DataFrame(processed_plant_data.toarray())
plant_data_df.index = plant_data.index

# %%
plant_data_df
# Out:
#                                                         0         1     \
# scientific_name
# Abelia chinensis                                   -0.069489 -0.067325
# Abelia 'Edward Goucher'                            -0.258145 -0.246987
# Abelia × grandiflora                               -0.258145 -0.187100
# Abelia × grandiflora 'Hopleys' MISS LEMON          -0.258145 -0.306874
# Abelia × grandiflora 'Kaleidoscope'                -0.352472 -0.396706
# ...                                                      ...       ...
# Diervilla rivularis 'Morton' SUMMER STARS          -0.352472 -0.366762
# Diervilla sessilifolia                             -0.258145 -0.246987
# Diervilla sessilifolia 'LPDC Podaras' COOL SPLASH  -0.352472 -0.366762
# Diervilla splendens 'El Madrigal' FIREFLY NIGHT... -0.352472 -0.366762
# Dietes bicolor                                     -0.399636 -0.426649
#
#                                                         2         3     \
# scientific_name
# Abelia chinensis                                   -0.187061 -0.176999
# Abelia 'Edward Goucher'                            -0.187061 -0.176999
# Abelia × grandiflora                               -0.187061 -0.089358
# Abelia × grandiflora 'Hopleys' MISS LEMON          -0.187061 -0.264640
# Abelia × grandiflora 'Kaleidoscope'                -0.187061 -0.264640
# ...                                                      ...       ...
# Diervilla rivularis 'Morton' SUMMER STARS          -0.187061 -0.264640
# Diervilla sessilifolia                             -0.187061 -0.176999
# Diervilla sessilifolia 'LPDC Podaras' COOL SPLASH  -0.324784 -0.352281
# Diervilla splendens 'El Madrigal' FIREFLY NIGHT... -0.324784 -0.352281
# Dietes bicolor                                     -0.496939 -0.527562
#
#                                                         4         5     \
# scientific_name
# Abelia chinensis                                    1.117528  0.273903
# Abelia 'Edward Goucher'                             0.606660  0.273903
# Abelia × grandiflora                                0.095792  0.273903
# Abelia × grandiflora 'Hopleys' MISS LEMON           0.606660  0.273903
# Abelia × grandiflora 'Kaleidoscope'                 0.095792  0.273903
# ...                                                      ...       ...
# Diervilla rivularis 'Morton' SUMMER STARS           0.095792 -1.387842
# Diervilla sessilifolia                              0.095792 -0.556969
# Diervilla sessilifolia 'LPDC Podaras' COOL SPLASH  -0.415077 -0.556969
# Diervilla splendens 'El Madrigal' FIREFLY NIGHT... -0.415077 -0.556969
# Dietes bicolor                                      2.139264  1.935649
#
#                                                         6         7     8     \
# scientific_name
# Abelia chinensis                                    1.060971  1.044536   0.0
# Abelia 'Edward Goucher'                            -0.279242  1.044536   1.0
# Abelia × grandiflora                               -0.279242  1.044536   0.0
# Abelia × grandiflora 'Hopleys' MISS LEMON          -0.279242  1.044536   0.0
# Abelia × grandiflora 'Kaleidoscope'                -0.279242  1.044536   0.0
# ...                                                      ...       ...   ...
# Diervilla rivularis 'Morton' SUMMER STARS           1.060971  0.508573   0.0
# Diervilla sessilifolia                              0.390864 -0.027391   0.0
# Diervilla sessilifolia 'LPDC Podaras' COOL SPLASH   0.390864 -0.027391   0.0
# Diervilla splendens 'El Madrigal' FIREFLY NIGHT... -0.279242 -0.027391   0.0
# Dietes bicolor                                     -0.279242  1.044536   0.0
#
#                                                     9     ...  6261  6262  \
# scientific_name                                           ...
# Abelia chinensis                                     0.0  ...   0.0   0.0
# Abelia 'Edward Goucher'                              0.0  ...   0.0   0.0
# Abelia × grandiflora                                 0.0  ...   0.0   0.0
# Abelia × grandiflora 'Hopleys' MISS LEMON            0.0  ...   0.0   0.0
# Abelia × grandiflora 'Kaleidoscope'                  0.0  ...   0.0   0.0
# ...                                                  ...  ...   ...   ...
# Diervilla rivularis 'Morton' SUMMER STARS            0.0  ...   0.0   0.0
# Diervilla sessilifolia                               0.0  ...   0.0   0.0
# Diervilla sessilifolia 'LPDC Podaras' COOL SPLASH    0.0  ...   0.0   0.0
# Diervilla splendens 'El Madrigal' FIREFLY NIGHT...   0.0  ...   0.0   0.0
# Dietes bicolor                                       0.0  ...   0.0   0.0
#
#                                                     6263  6264  6265  6266  \
# scientific_name
# Abelia chinensis                                     0.0   0.0   0.0   0.0
# Abelia 'Edward Goucher'                              0.0   0.0   0.0   0.0
# Abelia × grandiflora                                 0.0   0.0   0.0   0.0
# Abelia × grandiflora 'Hopleys' MISS LEMON            0.0   0.0   0.0   0.0
# Abelia × grandiflora 'Kaleidoscope'                  0.0   0.0   0.0   0.0
# ...                                                  ...   ...   ...   ...
# Diervilla rivularis 'Morton' SUMMER STARS            0.0   0.0   0.0   0.0
# Diervilla sessilifolia                               0.0   0.0   0.0   0.0
# Diervilla sessilifolia 'LPDC Podaras' COOL SPLASH    0.0   0.0   0.0   0.0
# Diervilla splendens 'El Madrigal' FIREFLY NIGHT...   0.0   0.0   0.0   0.0
# Dietes bicolor                                       0.0   0.0   0.0   0.0
#
#                                                     6267  6268  6269  6270
# scientific_name
# Abelia chinensis                                     0.0   0.0   0.0   0.0
# Abelia 'Edward Goucher'                              0.0   0.0   0.0   0.0
# Abelia × grandiflora                                 0.0   0.0   0.0   0.0
# Abelia × grandiflora 'Hopleys' MISS LEMON            0.0   0.0   0.0   0.0
# Abelia × grandiflora 'Kaleidoscope'                  0.0   0.0   0.0   0.0
# ...                                                  ...   ...   ...   ...
# Diervilla rivularis 'Morton' SUMMER STARS            0.0   0.0   0.0   0.0
# Diervilla sessilifolia                               0.0   0.0   0.0   0.0
# Diervilla sessilifolia 'LPDC Podaras' COOL SPLASH    0.0   0.0   0.0   0.0
# Diervilla splendens 'El Madrigal' FIREFLY NIGHT...   0.0   0.0   0.0   0.0
# Dietes bicolor                                       0.0   0.0   0.0   0.0
#
# [8448 rows x 6271 columns]

# %%
plant_data_df.isna().sum()
# Out:
# 0        0
# 1        0
# 2        2
# 3        2
# 4       11
#         ..
# 6266     0
# 6267     0
# 6268     0
# 6269     0
# 6270     0
# Length: 6271, dtype: int64

# %%
plant_data_df[plant_data_df.notnull()]
# Out:
#                                                         0         1     \
# scientific_name
# Abelia chinensis                                   -0.069489 -0.067325
# Abelia 'Edward Goucher'                            -0.258145 -0.246987
# Abelia × grandiflora                               -0.258145 -0.187100
# Abelia × grandiflora 'Hopleys' MISS LEMON          -0.258145 -0.306874
# Abelia × grandiflora 'Kaleidoscope'                -0.352472 -0.396706
# ...                                                      ...       ...
# Diervilla rivularis 'Morton' SUMMER STARS          -0.352472 -0.366762
# Diervilla sessilifolia                             -0.258145 -0.246987
# Diervilla sessilifolia 'LPDC Podaras' COOL SPLASH  -0.352472 -0.366762
# Diervilla splendens 'El Madrigal' FIREFLY NIGHT... -0.352472 -0.366762
# Dietes bicolor                                     -0.399636 -0.426649
#
#                                                         2         3     \
# scientific_name
# Abelia chinensis                                   -0.187061 -0.176999
# Abelia 'Edward Goucher'                            -0.187061 -0.176999
# Abelia × grandiflora                               -0.187061 -0.089358
# Abelia × grandiflora 'Hopleys' MISS LEMON          -0.187061 -0.264640
# Abelia × grandiflora 'Kaleidoscope'                -0.187061 -0.264640
# ...                                                      ...       ...
# Diervilla rivularis 'Morton' SUMMER STARS          -0.187061 -0.264640
# Diervilla sessilifolia                             -0.187061 -0.176999
# Diervilla sessilifolia 'LPDC Podaras' COOL SPLASH  -0.324784 -0.352281
# Diervilla splendens 'El Madrigal' FIREFLY NIGHT... -0.324784 -0.352281
# Dietes bicolor                                     -0.496939 -0.527562
#
#                                                         4         5     \
# scientific_name
# Abelia chinensis                                    1.117528  0.273903
# Abelia 'Edward Goucher'                             0.606660  0.273903
# Abelia × grandiflora                                0.095792  0.273903
# Abelia × grandiflora 'Hopleys' MISS LEMON           0.606660  0.273903
# Abelia × grandiflora 'Kaleidoscope'                 0.095792  0.273903
# ...                                                      ...       ...
# Diervilla rivularis 'Morton' SUMMER STARS           0.095792 -1.387842
# Diervilla sessilifolia                              0.095792 -0.556969
# Diervilla sessilifolia 'LPDC Podaras' COOL SPLASH  -0.415077 -0.556969
# Diervilla splendens 'El Madrigal' FIREFLY NIGHT... -0.415077 -0.556969
# Dietes bicolor                                      2.139264  1.935649
#
#                                                         6         7     8     \
# scientific_name
# Abelia chinensis                                    1.060971  1.044536   0.0
# Abelia 'Edward Goucher'                            -0.279242  1.044536   1.0
# Abelia × grandiflora                               -0.279242  1.044536   0.0
# Abelia × grandiflora 'Hopleys' MISS LEMON          -0.279242  1.044536   0.0
# Abelia × grandiflora 'Kaleidoscope'                -0.279242  1.044536   0.0
# ...                                                      ...       ...   ...
# Diervilla rivularis 'Morton' SUMMER STARS           1.060971  0.508573   0.0
# Diervilla sessilifolia                              0.390864 -0.027391   0.0
# Diervilla sessilifolia 'LPDC Podaras' COOL SPLASH   0.390864 -0.027391   0.0
# Diervilla splendens 'El Madrigal' FIREFLY NIGHT... -0.279242 -0.027391   0.0
# Dietes bicolor                                     -0.279242  1.044536   0.0
#
#                                                     9     ...  6261  6262  \
# scientific_name                                           ...
# Abelia chinensis                                     0.0  ...   0.0   0.0
# Abelia 'Edward Goucher'                              0.0  ...   0.0   0.0
# Abelia × grandiflora                                 0.0  ...   0.0   0.0
# Abelia × grandiflora 'Hopleys' MISS LEMON            0.0  ...   0.0   0.0
# Abelia × grandiflora 'Kaleidoscope'                  0.0  ...   0.0   0.0
# ...                                                  ...  ...   ...   ...
# Diervilla rivularis 'Morton' SUMMER STARS            0.0  ...   0.0   0.0
# Diervilla sessilifolia                               0.0  ...   0.0   0.0
# Diervilla sessilifolia 'LPDC Podaras' COOL SPLASH    0.0  ...   0.0   0.0
# Diervilla splendens 'El Madrigal' FIREFLY NIGHT...   0.0  ...   0.0   0.0
# Dietes bicolor                                       0.0  ...   0.0   0.0
#
#                                                     6263  6264  6265  6266  \
# scientific_name
# Abelia chinensis                                     0.0   0.0   0.0   0.0
# Abelia 'Edward Goucher'                              0.0   0.0   0.0   0.0
# Abelia × grandiflora                                 0.0   0.0   0.0   0.0
# Abelia × grandiflora 'Hopleys' MISS LEMON            0.0   0.0   0.0   0.0
# Abelia × grandiflora 'Kaleidoscope'                  0.0   0.0   0.0   0.0
# ...                                                  ...   ...   ...   ...
# Diervilla rivularis 'Morton' SUMMER STARS            0.0   0.0   0.0   0.0
# Diervilla sessilifolia                               0.0   0.0   0.0   0.0
# Diervilla sessilifolia 'LPDC Podaras' COOL SPLASH    0.0   0.0   0.0   0.0
# Diervilla splendens 'El Madrigal' FIREFLY NIGHT...   0.0   0.0   0.0   0.0
# Dietes bicolor                                       0.0   0.0   0.0   0.0
#
#                                                     6267  6268  6269  6270
# scientific_name
# Abelia chinensis                                     0.0   0.0   0.0   0.0
# Abelia 'Edward Goucher'                              0.0   0.0   0.0   0.0
# Abelia × grandiflora                                 0.0   0.0   0.0   0.0
# Abelia × grandiflora 'Hopleys' MISS LEMON            0.0   0.0   0.0   0.0
# Abelia × grandiflora 'Kaleidoscope'                  0.0   0.0   0.0   0.0
# ...                                                  ...   ...   ...   ...
# Diervilla rivularis 'Morton' SUMMER STARS            0.0   0.0   0.0   0.0
# Diervilla sessilifolia                               0.0   0.0   0.0   0.0
# Diervilla sessilifolia 'LPDC Podaras' COOL SPLASH    0.0   0.0   0.0   0.0
# Diervilla splendens 'El Madrigal' FIREFLY NIGHT...   0.0   0.0   0.0   0.0
# Dietes bicolor                                       0.0   0.0   0.0   0.0
#
# [8448 rows x 6271 columns]

# %%
plant_data_df_nona = plant_data_df.dropna()

# %%
plant_data_df_nona
# Out:
#                                                         0         1     \
# scientific_name
# Abelia chinensis                                   -0.069489 -0.067325
# Abelia 'Edward Goucher'                            -0.258145 -0.246987
# Abelia × grandiflora                               -0.258145 -0.187100
# Abelia × grandiflora 'Hopleys' MISS LEMON          -0.258145 -0.306874
# Abelia × grandiflora 'Kaleidoscope'                -0.352472 -0.396706
# ...                                                      ...       ...
# Diervilla rivularis 'Morton' SUMMER STARS          -0.352472 -0.366762
# Diervilla sessilifolia                             -0.258145 -0.246987
# Diervilla sessilifolia 'LPDC Podaras' COOL SPLASH  -0.352472 -0.366762
# Diervilla splendens 'El Madrigal' FIREFLY NIGHT... -0.352472 -0.366762
# Dietes bicolor                                     -0.399636 -0.426649
#
#                                                         2         3     \
# scientific_name
# Abelia chinensis                                   -0.187061 -0.176999
# Abelia 'Edward Goucher'                            -0.187061 -0.176999
# Abelia × grandiflora                               -0.187061 -0.089358
# Abelia × grandiflora 'Hopleys' MISS LEMON          -0.187061 -0.264640
# Abelia × grandiflora 'Kaleidoscope'                -0.187061 -0.264640
# ...                                                      ...       ...
# Diervilla rivularis 'Morton' SUMMER STARS          -0.187061 -0.264640
# Diervilla sessilifolia                             -0.187061 -0.176999
# Diervilla sessilifolia 'LPDC Podaras' COOL SPLASH  -0.324784 -0.352281
# Diervilla splendens 'El Madrigal' FIREFLY NIGHT... -0.324784 -0.352281
# Dietes bicolor                                     -0.496939 -0.527562
#
#                                                         4         5     \
# scientific_name
# Abelia chinensis                                    1.117528  0.273903
# Abelia 'Edward Goucher'                             0.606660  0.273903
# Abelia × grandiflora                                0.095792  0.273903
# Abelia × grandiflora 'Hopleys' MISS LEMON           0.606660  0.273903
# Abelia × grandiflora 'Kaleidoscope'                 0.095792  0.273903
# ...                                                      ...       ...
# Diervilla rivularis 'Morton' SUMMER STARS           0.095792 -1.387842
# Diervilla sessilifolia                              0.095792 -0.556969
# Diervilla sessilifolia 'LPDC Podaras' COOL SPLASH  -0.415077 -0.556969
# Diervilla splendens 'El Madrigal' FIREFLY NIGHT... -0.415077 -0.556969
# Dietes bicolor                                      2.139264  1.935649
#
#                                                         6         7     8     \
# scientific_name
# Abelia chinensis                                    1.060971  1.044536   0.0
# Abelia 'Edward Goucher'                            -0.279242  1.044536   1.0
# Abelia × grandiflora                               -0.279242  1.044536   0.0
# Abelia × grandiflora 'Hopleys' MISS LEMON          -0.279242  1.044536   0.0
# Abelia × grandiflora 'Kaleidoscope'                -0.279242  1.044536   0.0
# ...                                                      ...       ...   ...
# Diervilla rivularis 'Morton' SUMMER STARS           1.060971  0.508573   0.0
# Diervilla sessilifolia                              0.390864 -0.027391   0.0
# Diervilla sessilifolia 'LPDC Podaras' COOL SPLASH   0.390864 -0.027391   0.0
# Diervilla splendens 'El Madrigal' FIREFLY NIGHT... -0.279242 -0.027391   0.0
# Dietes bicolor                                     -0.279242  1.044536   0.0
#
#                                                     9     ...  6261  6262  \
# scientific_name                                           ...
# Abelia chinensis                                     0.0  ...   0.0   0.0
# Abelia 'Edward Goucher'                              0.0  ...   0.0   0.0
# Abelia × grandiflora                                 0.0  ...   0.0   0.0
# Abelia × grandiflora 'Hopleys' MISS LEMON            0.0  ...   0.0   0.0
# Abelia × grandiflora 'Kaleidoscope'                  0.0  ...   0.0   0.0
# ...                                                  ...  ...   ...   ...
# Diervilla rivularis 'Morton' SUMMER STARS            0.0  ...   0.0   0.0
# Diervilla sessilifolia                               0.0  ...   0.0   0.0
# Diervilla sessilifolia 'LPDC Podaras' COOL SPLASH    0.0  ...   0.0   0.0
# Diervilla splendens 'El Madrigal' FIREFLY NIGHT...   0.0  ...   0.0   0.0
# Dietes bicolor                                       0.0  ...   0.0   0.0
#
#                                                     6263  6264  6265  6266  \
# scientific_name
# Abelia chinensis                                     0.0   0.0   0.0   0.0
# Abelia 'Edward Goucher'                              0.0   0.0   0.0   0.0
# Abelia × grandiflora                                 0.0   0.0   0.0   0.0
# Abelia × grandiflora 'Hopleys' MISS LEMON            0.0   0.0   0.0   0.0
# Abelia × grandiflora 'Kaleidoscope'                  0.0   0.0   0.0   0.0
# ...                                                  ...   ...   ...   ...
# Diervilla rivularis 'Morton' SUMMER STARS            0.0   0.0   0.0   0.0
# Diervilla sessilifolia                               0.0   0.0   0.0   0.0
# Diervilla sessilifolia 'LPDC Podaras' COOL SPLASH    0.0   0.0   0.0   0.0
# Diervilla splendens 'El Madrigal' FIREFLY NIGHT...   0.0   0.0   0.0   0.0
# Dietes bicolor                                       0.0   0.0   0.0   0.0
#
#                                                     6267  6268  6269  6270
# scientific_name
# Abelia chinensis                                     0.0   0.0   0.0   0.0
# Abelia 'Edward Goucher'                              0.0   0.0   0.0   0.0
# Abelia × grandiflora                                 0.0   0.0   0.0   0.0
# Abelia × grandiflora 'Hopleys' MISS LEMON            0.0   0.0   0.0   0.0
# Abelia × grandiflora 'Kaleidoscope'                  0.0   0.0   0.0   0.0
# ...                                                  ...   ...   ...   ...
# Diervilla rivularis 'Morton' SUMMER STARS            0.0   0.0   0.0   0.0
# Diervilla sessilifolia                               0.0   0.0   0.0   0.0
# Diervilla sessilifolia 'LPDC Podaras' COOL SPLASH    0.0   0.0   0.0   0.0
# Diervilla splendens 'El Madrigal' FIREFLY NIGHT...   0.0   0.0   0.0   0.0
# Dietes bicolor                                       0.0   0.0   0.0   0.0
#
# [5645 rows x 6271 columns]

# %% [markdown]
# ## 2. Cosine Similarity

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
sim_matrix = cosine_similarity(plant_data_df_nona, plant_data_df_nona)

# %%
sim_matrix.shape
# Out:
# (5645, 5645)

# %%
df_sim = pd.DataFrame(sim_matrix, columns=plant_data_df_nona.index, index=plant_data_df_nona.index)

# %%
df_sim.head()
# Out:
# scientific_name                            Abelia chinensis  \
# scientific_name
# Abelia chinensis                                   1.000000
# Abelia 'Edward Goucher'                            0.716646
# Abelia × grandiflora                               0.675532
# Abelia × grandiflora 'Hopleys' MISS LEMON          0.715858
# Abelia × grandiflora 'Kaleidoscope'                0.766383
#
# scientific_name                            Abelia 'Edward Goucher'  \
# scientific_name
# Abelia chinensis                                          0.716646
# Abelia 'Edward Goucher'                                   1.000000
# Abelia × grandiflora                                      0.777708
# Abelia × grandiflora 'Hopleys' MISS LEMON                 0.796222
# Abelia × grandiflora 'Kaleidoscope'                       0.778903
#
# scientific_name                            Abelia × grandiflora  \
# scientific_name
# Abelia chinensis                                       0.675532
# Abelia 'Edward Goucher'                                0.777708
# Abelia × grandiflora                                   1.000000
# Abelia × grandiflora 'Hopleys' MISS LEMON              0.880638
# Abelia × grandiflora 'Kaleidoscope'                    0.890628
#
# scientific_name                            Abelia × grandiflora 'Hopleys' MISS LEMON  \
# scientific_name
# Abelia chinensis                                                            0.715858
# Abelia 'Edward Goucher'                                                     0.796222
# Abelia × grandiflora                                                        0.880638
# Abelia × grandiflora 'Hopleys' MISS LEMON                                   1.000000
# Abelia × grandiflora 'Kaleidoscope'                                         0.883354
#
# scientific_name                            Abelia × grandiflora 'Kaleidoscope'  \
# scientific_name
# Abelia chinensis                                                      0.766383
# Abelia 'Edward Goucher'                                               0.778903
# Abelia × grandiflora                                                  0.890628
# Abelia × grandiflora 'Hopleys' MISS LEMON                             0.883354
# Abelia × grandiflora 'Kaleidoscope'                                   1.000000
#
# scientific_name                            Abelia × grandiflora 'MINDUO1' SUNNY ANNIVERSARY  \
# scientific_name
# Abelia chinensis                                                                   0.689328
# Abelia 'Edward Goucher'                                                            0.596739
# Abelia × grandiflora                                                               0.672720
# Abelia × grandiflora 'Hopleys' MISS LEMON                                          0.693508
# Abelia × grandiflora 'Kaleidoscope'                                                0.678065
#
# scientific_name                            Abelia × grandiflora 'Minipan' GOLDEN ANNIVERSARY  \
# scientific_name
# Abelia chinensis                                                                    0.800767
# Abelia 'Edward Goucher'                                                             0.793332
# Abelia × grandiflora                                                                0.875197
# Abelia × grandiflora 'Hopleys' MISS LEMON                                           0.894899
# Abelia × grandiflora 'Kaleidoscope'                                                 0.982730
#
# scientific_name                            Abelia × grandiflora 'Panache' SILVER ANNIVERSARY  \
# scientific_name
# Abelia chinensis                                                                    0.800767
# Abelia 'Edward Goucher'                                                             0.793332
# Abelia × grandiflora                                                                0.875197
# Abelia × grandiflora 'Hopleys' MISS LEMON                                           0.894899
# Abelia × grandiflora 'Kaleidoscope'                                                 0.982730
#
# scientific_name                            Abelia × grandiflora 'Sherwoodii'  \
# scientific_name
# Abelia chinensis                                                    0.674935
# Abelia 'Edward Goucher'                                             0.779013
# Abelia × grandiflora                                                0.891910
# Abelia × grandiflora 'Hopleys' MISS LEMON                           0.883587
# Abelia × grandiflora 'Kaleidoscope'                                 0.894742
#
# scientific_name                            Abelia mosanensis 'SMNAMDS' SWEET EMOTION  \
# scientific_name
# Abelia chinensis                                                            0.443271
# Abelia 'Edward Goucher'                                                     0.550087
# Abelia × grandiflora                                                        0.582972
# Abelia × grandiflora 'Hopleys' MISS LEMON                                   0.550109
# Abelia × grandiflora 'Kaleidoscope'                                         0.582228
#
# scientific_name                            ...  \
# scientific_name                            ...
# Abelia chinensis                           ...
# Abelia 'Edward Goucher'                    ...
# Abelia × grandiflora                       ...
# Abelia × grandiflora 'Hopleys' MISS LEMON  ...
# Abelia × grandiflora 'Kaleidoscope'        ...
#
# scientific_name                            Dictamnus albus var. purpureus  \
# scientific_name
# Abelia chinensis                                                 0.101824
# Abelia 'Edward Goucher'                                          0.209503
# Abelia × grandiflora                                             0.257239
# Abelia × grandiflora 'Hopleys' MISS LEMON                        0.214042
# Abelia × grandiflora 'Kaleidoscope'                              0.271450
#
# scientific_name                            Dierama igneum  Dierama pendulum  \
# scientific_name
# Abelia chinensis                                 0.531542          0.407872
# Abelia 'Edward Goucher'                          0.412553          0.348636
# Abelia × grandiflora                             0.362932          0.292263
# Abelia × grandiflora 'Hopleys' MISS LEMON        0.416809          0.353336
# Abelia × grandiflora 'Kaleidoscope'              0.376920          0.307269
#
# scientific_name                            Diervilla lonicera  \
# scientific_name
# Abelia chinensis                                     0.359168
# Abelia 'Edward Goucher'                              0.398642
# Abelia × grandiflora                                 0.448599
# Abelia × grandiflora 'Hopleys' MISS LEMON            0.401450
# Abelia × grandiflora 'Kaleidoscope'                  0.457880
#
# scientific_name                            Diervilla rivularis  \
# scientific_name
# Abelia chinensis                                      0.642902
# Abelia 'Edward Goucher'                               0.568581
# Abelia × grandiflora                                  0.575722
# Abelia × grandiflora 'Hopleys' MISS LEMON             0.566854
# Abelia × grandiflora 'Kaleidoscope'                   0.573070
#
# scientific_name                            Diervilla rivularis 'Morton' SUMMER STARS  \
# scientific_name
# Abelia chinensis                                                            0.645061
# Abelia 'Edward Goucher'                                                     0.577032
# Abelia × grandiflora                                                        0.580451
# Abelia × grandiflora 'Hopleys' MISS LEMON                                   0.579133
# Abelia × grandiflora 'Kaleidoscope'                                         0.587866
#
# scientific_name                            Diervilla sessilifolia  \
# scientific_name
# Abelia chinensis                                         0.542314
# Abelia 'Edward Goucher'                                  0.538217
# Abelia × grandiflora                                     0.541002
# Abelia × grandiflora 'Hopleys' MISS LEMON                0.539531
# Abelia × grandiflora 'Kaleidoscope'                      0.545889
#
# scientific_name                            Diervilla sessilifolia 'LPDC Podaras' COOL SPLASH  \
# scientific_name
# Abelia chinensis                                                                    0.480026
# Abelia 'Edward Goucher'                                                             0.503491
# Abelia × grandiflora                                                                0.531503
# Abelia × grandiflora 'Hopleys' MISS LEMON                                           0.507222
# Abelia × grandiflora 'Kaleidoscope'                                                 0.543115
#
# scientific_name                            Diervilla splendens 'El Madrigal' FIREFLY NIGHTGLOW  \
# scientific_name
# Abelia chinensis                                                                    0.412663
# Abelia 'Edward Goucher'                                                             0.525432
# Abelia × grandiflora                                                                0.553986
# Abelia × grandiflora 'Hopleys' MISS LEMON                                           0.529105
# Abelia × grandiflora 'Kaleidoscope'                                                 0.565389
#
# scientific_name                            Dietes bicolor
# scientific_name
# Abelia chinensis                                 0.544966
# Abelia 'Edward Goucher'                          0.550911
# Abelia × grandiflora                             0.474082
# Abelia × grandiflora 'Hopleys' MISS LEMON        0.554234
# Abelia × grandiflora 'Kaleidoscope'              0.484599
#
# [5 rows x 5645 columns]

# %% [markdown]
# ## 3. Model Demo

# %%
def recommend(plant):
    scores=list(enumerate(df_sim[plant]))
    sorted_scores=sorted(scores,key=lambda x:x[1],reverse=True)
    plants=[plant[0] for plant in sorted_scores]
    return plants

# %%
def recommend_five(plant_list, target_common_name):
    seen_common_names = set()
    seen_common_names.add(target_common_name)
    print(seen_common_names)
    first_five=[]
    count=0
    for plant_index in plant_list:
        if count > 4:
            break
        if (plant_index < len(plant_data_nona)):
            recRow = plant_data_nona.iloc[plant_index]
            if recRow.common_name not in seen_common_names:
                count+=1
                first_five.append(recRow.name)
                seen_common_names.add(recRow.common_name)
    print(seen_common_names)
    return first_five

# %%
target_plant = "oak"

# %%
plant_data_nona[plant_data_nona["common_name"].str.lower().str.contains(target_plant)]
# Out:
#                                                    common_name         family  \
# scientific_name
# Hydrangea quercifolia                        Oakleaf Hydrangea  Hydrangeaceae
# Hydrangea quercifolia 'Alice'                Oakleaf Hydrangea  Hydrangeaceae
# Hydrangea quercifolia 'Brido' SNOW FLAKE     Oakleaf Hydrangea  Hydrangeaceae
# Hydrangea quercifolia 'Flemygea' SNOW QUEEN  Oakleaf Hydrangea  Hydrangeaceae
# Hydrangea quercifolia 'Little Honey'         Oakleaf Hydrangea  Hydrangeaceae
# Hydrangea quercifolia 'Munchkin'             Oakleaf Hydrangea  Hydrangeaceae
# Hydrangea quercifolia 'Pee Wee'              Oakleaf Hydrangea  Hydrangeaceae
# Hydrangea quercifolia 'Piihq-i' JETSTREAM    Oakleaf Hydrangea  Hydrangeaceae
# Hydrangea quercifolia 'Queen of Hearts'      Oakleaf Hydrangea  Hydrangeaceae
# Hydrangea quercifolia 'Ruby Slippers'        Oakleaf Hydrangea  Hydrangeaceae
# Hydrangea quercifolia 'Vaughn's Lillie'      Oakleaf Hydrangea  Hydrangeaceae
# Quercus coccifera                                   Kermes Oak       Fagaceae
# Quercus ilex                                          Holm Oak       Fagaceae
# Quercus myrtifolia                                  Myrtle Oak       Fagaceae
# Quercus pontica                                   Armenian Oak       Fagaceae
#
#                                              height_min  height_max  \
# scientific_name
# Hydrangea quercifolia                               6.0         8.0
# Hydrangea quercifolia 'Alice'                       5.0         8.0
# Hydrangea quercifolia 'Brido' SNOW FLAKE            5.0         8.0
# Hydrangea quercifolia 'Flemygea' SNOW QUEEN         4.0         6.0
# Hydrangea quercifolia 'Little Honey'                3.0         4.0
# Hydrangea quercifolia 'Munchkin'                    3.0         4.5
# Hydrangea quercifolia 'Pee Wee'                     3.0         4.0
# Hydrangea quercifolia 'Piihq-i' JETSTREAM           5.0         6.0
# Hydrangea quercifolia 'Queen of Hearts'             5.0         6.0
# Hydrangea quercifolia 'Ruby Slippers'               3.0         4.0
# Hydrangea quercifolia 'Vaughn's Lillie'             3.0         4.0
# Quercus coccifera                                   6.0        12.0
# Quercus ilex                                       40.0        70.0
# Quercus myrtifolia                                 15.0        20.0
# Quercus pontica                                    10.0        20.0
#
#                                              spread_min  spread_max  \
# scientific_name
# Hydrangea quercifolia                               6.0         8.0
# Hydrangea quercifolia 'Alice'                       5.0         8.0
# Hydrangea quercifolia 'Brido' SNOW FLAKE            5.0        10.0
# Hydrangea quercifolia 'Flemygea' SNOW QUEEN         6.0         8.0
# Hydrangea quercifolia 'Little Honey'                4.0         5.0
# Hydrangea quercifolia 'Munchkin'                    3.0         4.5
# Hydrangea quercifolia 'Pee Wee'                     2.5         3.0
# Hydrangea quercifolia 'Piihq-i' JETSTREAM           4.0         5.0
# Hydrangea quercifolia 'Queen of Hearts'             7.0         9.0
# Hydrangea quercifolia 'Ruby Slippers'               3.0         5.0
# Hydrangea quercifolia 'Vaughn's Lillie'             3.0         5.0
# Quercus coccifera                                   6.0        12.0
# Quercus ilex                                       40.0        70.0
# Quercus myrtifolia                                  8.0        10.0
# Quercus pontica                                     8.0        18.0
#
#                                                             type maintenance  \
# scientific_name
# Hydrangea quercifolia                            Deciduous shrub         Low
# Hydrangea quercifolia 'Alice'                    Deciduous shrub         Low
# Hydrangea quercifolia 'Brido' SNOW FLAKE         Deciduous shrub         Low
# Hydrangea quercifolia 'Flemygea' SNOW QUEEN      Deciduous shrub         Low
# Hydrangea quercifolia 'Little Honey'             Deciduous shrub         Low
# Hydrangea quercifolia 'Munchkin'                 Deciduous shrub         Low
# Hydrangea quercifolia 'Pee Wee'                  Deciduous shrub         Low
# Hydrangea quercifolia 'Piihq-i' JETSTREAM        Deciduous shrub         Low
# Hydrangea quercifolia 'Queen of Hearts'          Deciduous shrub         Low
# Hydrangea quercifolia 'Ruby Slippers'            Deciduous shrub         Low
# Hydrangea quercifolia 'Vaughn's Lillie'          Deciduous shrub         Low
# Quercus coccifera                                           Tree         Low
# Quercus ilex                                 Broadleaf evergreen         Low
# Quercus myrtifolia                           Broadleaf evergreen         Low
# Quercus pontica                                             Tree      Medium
#
#                                               sun_max     sun_min  \
# scientific_name
# Hydrangea quercifolia                        full sun  part shade
# Hydrangea quercifolia 'Alice'                full sun  part shade
# Hydrangea quercifolia 'Brido' SNOW FLAKE     full sun  part shade
# Hydrangea quercifolia 'Flemygea' SNOW QUEEN  full sun  part shade
# Hydrangea quercifolia 'Little Honey'         full sun  part shade
# Hydrangea quercifolia 'Munchkin'             full sun  part shade
# Hydrangea quercifolia 'Pee Wee'              full sun  part shade
# Hydrangea quercifolia 'Piihq-i' JETSTREAM    full sun  part shade
# Hydrangea quercifolia 'Queen of Hearts'      full sun  part shade
# Hydrangea quercifolia 'Ruby Slippers'        full sun  part shade
# Hydrangea quercifolia 'Vaughn's Lillie'      full sun  part shade
# Quercus coccifera                            full sun  part shade
# Quercus ilex                                 full sun  part shade
# Quercus myrtifolia                           full sun  part shade
# Quercus pontica                              full sun  part shade
#
#                                                      water  zone_min  \
# scientific_name
# Hydrangea quercifolia                               Medium       5.0
# Hydrangea quercifolia 'Alice'                       Medium       5.0
# Hydrangea quercifolia 'Brido' SNOW FLAKE            Medium       5.0
# Hydrangea quercifolia 'Flemygea' SNOW QUEEN         Medium       5.0
# Hydrangea quercifolia 'Little Honey'                Medium       5.0
# Hydrangea quercifolia 'Munchkin'                    Medium       5.0
# Hydrangea quercifolia 'Pee Wee'                     Medium       5.0
# Hydrangea quercifolia 'Piihq-i' JETSTREAM           Medium       5.0
# Hydrangea quercifolia 'Queen of Hearts'             Medium       5.0
# Hydrangea quercifolia 'Ruby Slippers'               Medium       5.0
# Hydrangea quercifolia 'Vaughn's Lillie'             Medium       5.0
# Quercus coccifera                                   Medium       6.0
# Quercus ilex                                        Medium       7.0
# Quercus myrtifolia                           Dry to medium       8.0
# Quercus pontica                                     Medium       5.0
#
#                                              zone_max  \
# scientific_name
# Hydrangea quercifolia                             9.0
# Hydrangea quercifolia 'Alice'                     9.0
# Hydrangea quercifolia 'Brido' SNOW FLAKE          9.0
# Hydrangea quercifolia 'Flemygea' SNOW QUEEN       9.0
# Hydrangea quercifolia 'Little Honey'              9.0
# Hydrangea quercifolia 'Munchkin'                  9.0
# Hydrangea quercifolia 'Pee Wee'                   9.0
# Hydrangea quercifolia 'Piihq-i' JETSTREAM         9.0
# Hydrangea quercifolia 'Queen of Hearts'           9.0
# Hydrangea quercifolia 'Ruby Slippers'             9.0
# Hydrangea quercifolia 'Vaughn's Lillie'           9.0
# Quercus coccifera                                 8.0
# Quercus ilex                                     10.0
# Quercus myrtifolia                               10.0
# Quercus pontica                                  10.0
#
#                                                                   bloom_desc  \
# scientific_name
# Hydrangea quercifolia                        White changing to purplish pink
# Hydrangea quercifolia 'Alice'                           White fading to pink
# Hydrangea quercifolia 'Brido' SNOW FLAKE                      White (double)
# Hydrangea quercifolia 'Flemygea' SNOW QUEEN           White changing to pink
# Hydrangea quercifolia 'Little Honey'                                   White
# Hydrangea quercifolia 'Munchkin'                         White aging to pink
# Hydrangea quercifolia 'Pee Wee'                         White fading to pink
# Hydrangea quercifolia 'Piihq-i' JETSTREAM       White maturing to light pink
# Hydrangea quercifolia 'Queen of Hearts'                  White aging to pink
# Hydrangea quercifolia 'Ruby Slippers'             White maturing to ruby red
# Hydrangea quercifolia 'Vaughn's Lillie'                                White
# Quercus coccifera                                            Yellowish-green
# Quercus ilex                                                 Yellowish-green
# Quercus myrtifolia                                                  Greenish
# Quercus pontica                                                 Olive-yellow
#
#                                              bloom_start_month  \
# scientific_name
# Hydrangea quercifolia                                      5.0
# Hydrangea quercifolia 'Alice'                              6.0
# Hydrangea quercifolia 'Brido' SNOW FLAKE                   6.0
# Hydrangea quercifolia 'Flemygea' SNOW QUEEN                5.0
# Hydrangea quercifolia 'Little Honey'                       6.0
# Hydrangea quercifolia 'Munchkin'                           6.0
# Hydrangea quercifolia 'Pee Wee'                            6.0
# Hydrangea quercifolia 'Piihq-i' JETSTREAM                  6.0
# Hydrangea quercifolia 'Queen of Hearts'                    6.0
# Hydrangea quercifolia 'Ruby Slippers'                      6.0
# Hydrangea quercifolia 'Vaughn's Lillie'                    6.0
# Quercus coccifera                                          3.0
# Quercus ilex                                               4.0
# Quercus myrtifolia                                         4.0
# Quercus pontica                                            4.0
#
#                                              bloom_end_month
# scientific_name
# Hydrangea quercifolia                                    7.0
# Hydrangea quercifolia 'Alice'                            7.0
# Hydrangea quercifolia 'Brido' SNOW FLAKE                 7.0
# Hydrangea quercifolia 'Flemygea' SNOW QUEEN              7.0
# Hydrangea quercifolia 'Little Honey'                     7.0
# Hydrangea quercifolia 'Munchkin'                         7.0
# Hydrangea quercifolia 'Pee Wee'                          7.0
# Hydrangea quercifolia 'Piihq-i' JETSTREAM                7.0
# Hydrangea quercifolia 'Queen of Hearts'                  7.0
# Hydrangea quercifolia 'Ruby Slippers'                    7.0
# Hydrangea quercifolia 'Vaughn's Lillie'                  7.0
# Quercus coccifera                                        5.0
# Quercus ilex                                             5.0
# Quercus myrtifolia                                       5.0
# Quercus pontica                                          5.0

# %%
target_plant = "Quercus ilex"

# %%
lst=recommend(target_plant)
target_index = lst[0]
target_common_name = plant_data_nona.iloc[target_index].common_name

recommended=recommend_five(lst, target_common_name)
# Out:
# {'Montbretia'}
# {'Cranesbill', 'Montbretia', 'Cotoneaster', 'Saffron Crocus', 'Medlar-hawthorn', 'Pigsqueak'}

# %%
recommended
# Out:
# ['Crocus sativus',
#  "Geranium cinereum 'Purple Pillow'",
#  'Cotoneaster suavis',
#  "Bergenia cordifolia 'Miss Piggy'",
#  "× Crataegomespilus 'Dardarii'"]
