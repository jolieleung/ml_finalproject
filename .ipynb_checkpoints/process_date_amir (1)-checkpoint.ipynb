# %%
import pandas as pd

# %%
df_plants = pd.read_csv("all-plant-data.csv")

# %%
df_plants.columns
# Out:
# Index(['scientific_name', 'common_name', 'family', 'height (feet)',
#        'height_min', 'height_max', 'spread (feet)', 'spread_min', 'spread_max',
#        'type', 'bloom_time', 'bloom_start', 'bloom_end', 'maintenance', 'sun',
#        'sun_max', 'sun_min', 'water', 'zone', 'zone_min', 'zone_max',
#        'bloom_desc', 'native_range'],
#       dtype='object')

# %%
df_plants.shape
# Out:
# (8448, 23)

# %%
df_plants = df_plants.dropna()
df_plants.shape
# Out:
# (1194, 23)

# %%
# cast bloom time as string -> to avoid NaNs causing issue later
df_plants["bloom_time"] = df_plants["bloom_time"].astype(str)

# %%
# split on "to" and create 2 new columns
df_plants[["bloom_start", "blomm_end"]] = df_plants["bloom_time"].str.split(" to ", expand=True)

# %%
# remove leading and trailing whitespaces
df_plants["bloom_start"] = df_plants["bloom_start"].apply(lambda x: x.strip())
df_plants["blomm_end"] = df_plants["blomm_end"].apply(lambda x: x.strip())

# %%
# get the format from here: https://strftime.org/
df_plants[["bloom_start", "bloom_end"]] = df_plants[["bloom_start", "bloom_end"]].apply(pd.to_datetime, format="%B", errors="coerce")

# %% [markdown]
# You can either use the months (12 features for each column) or convert them to seasons (in order to have less features based on just date)

# %%
# OPTION 1
# extracting month

df_plants["bloom_start_month"] = df_plants["bloom_start"].apply(lambda x: x.month)
df_plants["bloom_end_month"] = df_plants["bloom_end"].apply(lambda x: x.month)

# %%
# option 2 - find seasons
df_plants[["bloom_start_season", "bloom_end_season"]] = df_plants[["bloom_start_month", "bloom_end_month"]].apply(lambda x: x%12 // 3 + 1)

# %%
assert df_plants["bloom_start_season"].value_counts().sum() == df_plants["bloom_start_month"].value_counts().sum()

# %%
df_plants
# Out:
#               scientific_name                common_name          family  \
# 0            Abelia chinensis             Chinese Abelia  Caprifoliaceae
# 2        Abelia × grandiflora              Glossy Abelia  Caprifoliaceae
# 11    Abeliophyllum distichum            White Forsythia        Oleaceae
# 24          Aconitum napellus                  Monkshood   Ranunculaceae
# 26          Aconitum volubile                  Monkshood   Ranunculaceae
# ...                       ...                        ...             ...
# 8416        Diarrhena obovata         American Beakgrain         Poaceae
# 8441       Diervilla lonicera           Bush Honeysuckle  Caprifoliaceae
# 8442      Diervilla rivularis  Mountain Bush Honeysuckle  Caprifoliaceae
# 8444   Diervilla sessilifolia           Bush Honeysuckle  Caprifoliaceae
# 8447           Dietes bicolor             Butterfly Flag       Iridaceae
#
#       height (feet)  height_min  height_max spread (feet)  spread_min  \
# 0      5.00 to 8.00         5.0         8.0  3.00 to 5.00        3.00
# 2      3.00 to 6.00         3.0         6.0  3.00 to 6.00        3.00
# 11     3.00 to 5.00         3.0         5.0  3.00 to 4.00        3.00
# 24     2.00 to 4.00         2.0         4.0  1.00 to 1.50        1.00
# 26    8.00 to 12.00         8.0        12.0  1.50 to 3.00        1.50
# ...             ...         ...         ...           ...         ...
# 8416   2.00 to 3.00         2.0         3.0  2.00 to 3.00        2.00
# 8441   2.00 to 3.00         2.0         3.0  2.00 to 4.00        2.00
# 8442   3.00 to 6.00         3.0         6.0  4.00 to 8.00        4.00
# 8444   3.00 to 5.00         3.0         5.0  3.00 to 5.00        3.00
# 8447   1.50 to 2.00         1.5         2.0  0.75 to 1.00        0.75
#
#       spread_max                  type  ...     zone zone_min zone_max  \
# 0            5.0       Deciduous shrub  ...   7 to 9      7.0      9.0
# 2            6.0       Deciduous shrub  ...   5 to 9      5.0      9.0
# 11           4.0       Deciduous shrub  ...   5 to 8      5.0      8.0
# 24           1.5  Herbaceous perennial  ...   3 to 7      3.0      7.0
# 26           3.0                  Vine  ...   4 to 8      4.0      8.0
# ...          ...                   ...  ...      ...      ...      ...
# 8416         3.0      Ornamental grass  ...   4 to 8      4.0      8.0
# 8441         4.0       Deciduous shrub  ...   3 to 7      3.0      7.0
# 8442         8.0       Deciduous shrub  ...   5 to 7      5.0      7.0
# 8444         5.0       Deciduous shrub  ...   5 to 8      5.0      8.0
# 8447         1.0                  Bulb  ...  9 to 11      9.0     11.0
#
#                                        bloom_desc  \
# 0                                           White
# 2                              White/flushed pink
# 11             White, sometimes with a pink tinge
# 24                             Deep purplish blue
# 26                                         Purple
# ...                                           ...
# 8416                    Green with yellow anthers
# 8441                                       Yellow
# 8442                                       Yellow
# 8444                                Sulfur yellow
# 8447  Light yellow with dark brown tepal blotches
#
#                      native_range  blomm_end bloom_start_month  \
# 0                           China  September                 7
# 2                  origin unknown  September                 5
# 11                          Korea      April                 3
# 24                         Europe     August                 7
# 26                   Eastern Asia  September                 8
# ...                           ...        ...               ...
# 8416        United States, Canada    October                 6
# 8441        Eastern North America       July                 6
# 8442   Southeastern United States     August                 7
# 8444   Southeastern United States       July                 6
# 8447                 South Africa  September                 5
#
#      bloom_end_month bloom_start_season  bloom_end_season
# 0                9.0                  3               4.0
# 2                9.0                  2               4.0
# 11               4.0                  2               2.0
# 24               8.0                  3               3.0
# 26               9.0                  3               4.0
# ...              ...                ...               ...
# 8416            10.0                  3               4.0
# 8441             7.0                  3               3.0
# 8442             8.0                  3               3.0
# 8444             7.0                  3               3.0
# 8447             9.0                  2               4.0
#
# [1194 rows x 28 columns]
